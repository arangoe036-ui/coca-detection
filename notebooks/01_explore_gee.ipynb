# %% [markdown]
# # 01 — Explore GEE (P1a)
# Interactively inspect Sentinel-2/1 collections, cloud masking, and seasonal composites for the AOI before exporting tiles. See plan §6.1.
#
# **Do not run heavy exports until plan §13 Q1–Q3 are confirmed.**

# %%
import sys; sys.path.append('..')
from src.utils import load_config
cfg = load_config('../config/default.yaml')
cfg['aoi'], cfg['year']
