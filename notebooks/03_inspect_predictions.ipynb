# %% [markdown]
# # 03 — Inspect predictions (P3 / P4)
# Overlay predicted coca probability on imagery; review error cases (coca vs pasture/other crops/regrowth); compare predicted hectares to the official figure. See plan §8–9.

# %%
import sys; sys.path.append('..')
from src.utils import load_config
cfg = load_config('../config/default.yaml')
cfg['eval']
