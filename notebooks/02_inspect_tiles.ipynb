# %% [markdown]
# # 02 — Inspect tiles & label overlap (P1b / P1c)
# Verify the rasterized coca mask overlaps imagery correctly, and check tile counts per spatial split. See plan §6.2–6.3.

# %%
import sys; sys.path.append('..')
from src.utils import load_config
cfg = load_config('../config/default.yaml')
cfg['tiling']
